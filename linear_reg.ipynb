# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("CCPP_data.csv", header=0)    # header is non (it  will use for txt file )
data.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4    NaN  37.50  1009.23  96.62  473.90

# %%
data.shape
# Out:
# (9568, 5)

# %%
data.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %%
data.describe(include="all")
# Out:
#                 AT            V           AP           RH           PE
# count  9567.000000  9568.000000  9565.000000  9565.000000  9568.000000
# mean     19.652154    54.305804  1013.259152    73.307947   454.365009
# std       7.452316    12.707893     5.936917    14.601948    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.320000   439.750000
# 50%      20.350000    52.080000  1012.940000    74.970000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
data.dtypes
# Out:
# AT    float64
# V     float64
# AP    float64
# RH    float64
# PE    float64
# dtype: object

# %%
np.size(data)    #(shape9568*5)=47840  np.size meaning all row and all columns count all
# Out:
# 47840

# %%
a=[[8,9,0],[1,8,9],[1,0,5]]
np.size(a)    #np size means all number count
np.unique(a)   #whatever unique numbers 
np.size(np.unique(a,return_counts=True)[0])        #return_counts  means how many unique values return it will show   # zero in size it will take index
# Out:
# 5

# %%
np.size(np.unique(data.PE, return_counts=True)[0])
# Out:
# 4836

# %%
data.drop('', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-0b3883f16ce9> in <module>
# ----> 1 data.drop('', axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
data.isnull().sum()
# Out:
# AT    1
# V     0
# AP    3
# RH    3
# PE    0
# dtype: int64

# %%
dat=data.fillna(data.median(),inplace=True)

# %%
data.isnull()
print(data.columns)
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %%
data.dtypes    #float 64 is a bytes
# Out:
# AT    float64
# V     float64
# AP    float64
# RH    float64
# PE    float64
# dtype: object

# %%
num=data.select_dtypes(include=['int64','float64']).columns
num
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %%
data[num].corr()
# Out:
#           AT         V        AP        RH        PE
# AT  1.000000  0.843992 -0.507389 -0.542383 -0.948045
# V   0.843992  1.000000 -0.413059 -0.312208 -0.869780
# AP -0.507389 -0.413059  1.000000  0.100051  0.518046
# RH -0.542383 -0.312208  0.100051  1.000000  0.389809
# PE -0.948045 -0.869780  0.518046  0.389809  1.000000

# %%
pd.scatter_matrix(data, figsize=(16,16), diagonal='kde')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(16,16))
data1=data.iloc[:,0:4]
sns.heatmap(data1.corr())
plt.show()

# %%
sns.countplot(x='PE',data=data)
plt.show()

# %%
sns.distplot(data['PE'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data=pd.read_csv('CustomerData.csv',header=0)
data.head()
# Out:
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
# 1        1002     1             2              3              6     442
# 2        1003     1             4              3              5     424
# 3        1004     1             1              6              6     261
# 4        1005     1             3              6              9     422
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
# 1                 20                  20              245               22
# 2                 18                  18             1059              130
# 3                 11                   9              365               34
# 4                 44                  31             1066              102
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# ...

# %%
cols_to_transform=data.select_dtypes(include=['category']).columns
cols_to_transform
# Out:
# Index([], dtype='object')

# %%
print(data.columns)
cols = data.columns.values
print(cols)
# Out:
# Index(['CustomerID', 'City', 'NoOfChildren', 'MinAgeOfChild', 'MaxAgeOfChild',
#        'Tenure', 'FrquncyOfPurchase', 'NoOfUnitsPurchased', 'FrequencyOFPlay',
#        'NoOfGamesPlayed', 'NoOfGamesBought', 'FavoriteChannelOfTransaction',
#        'FavoriteGame', 'TotalRevenueGenerated'],
#       dtype='object')
# ['CustomerID' 'City' 'NoOfChildren' 'MinAgeOfChild' 'MaxAgeOfChild'
#  'Tenure' 'FrquncyOfPurchase' 'NoOfUnitsPurchased' 'FrequencyOFPlay'
#  'NoOfGamesPlayed' 'NoOfGamesBought' 'FavoriteChannelOfTransaction'
#  'FavoriteGame' 'TotalRevenueGenerated']

# %%
data.head(3)
# Out:
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
# 1        1002     1             2              3              6     442
# 2        1003     1             4              3              5     424
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
# 1                 20                  20              245               22
# 2                 18                  18             1059              130
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# 0               10                      Uniform      Uniform
# 1                7                     Favorite      Uniform
# 2               18                     Favorite      Uniform
#
#    TotalRevenueGenerated
# 0                 107.51
# 1                 382.40
# 2                 135.01
